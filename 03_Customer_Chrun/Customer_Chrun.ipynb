# %% [markdown]
# # 고객 이탈 예측
# ## KNN (Binary Classification)

# %% [markdown]
# 이동통신사 고객 데이터를 바탕으로 고객의 이탈을 예측한다.

# %% [markdown]
# ## 참고: KNN Algorithm
#
# ### = K-Nearest Neighbors Algorithm (K-최근접 이웃 알고리즘)
#
# 새로운 데이터가 주어졌을 때 가장 근접한 K개 관측치를 선정하고
# 선정된 데이터가 가장 많이 분포한 분류를 선택한다.
#
# K개의 가까운 관측치만을 고려하므로 오류 데이터나 결측치가 결과에 영향을 주지 않으며
# 기존 데이터를 기반으로 하므로 데이터에 대한 가정이 없다.
# 또한 기존 분류 체계의 값을 모두 검사하므로 정확도가 높다.
#
# 모든 데이터를 검사하기 때문에 처리 속도가 느리고 메모리 사용이 많으므로
# 고차원 데이터에 적용하기 위해서는 차원 축소 과정을 거친다.
# 결과와 무관한 특징이 존재하거나 특징 크기가 중요성과 일치하지 않을 경우 정확도가 상당히 감소한다.
#
# 당연히 매개변수 K의 최적값을 결정하는 것이 중요하고
# 동률의 투표값을 제외하기 위해 홀수 K값을 사용하는 것이 바람직하다.

# %% [markdown]
# ## 모듈 및 데이터 로드

# %%
# 모듈 로드

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 데이터 로드

data = pd.read_csv('churn.csv')

# %% [markdown]
# ## 데이터 특성 확인

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.shape
# Out:
# (7043, 21)

# %%
pd.set_option('display.max_columns', 30)

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# TotalCharges Column의 Data type이 object로 정의되었음을 확인

data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
# pd.to_numeric(data['TotalCharges']) -> ValueError at position 488
data.iloc[488]
# Out:
# customerID                         4472-LVYGI
# gender                                 Female
# SeniorCitizen                               0
# Partner                                   Yes
# Dependents                                Yes
# tenure                                      0
# PhoneService                               No
# MultipleLines                No phone service
# InternetService                           DSL
# OnlineSecurity                            Yes
# OnlineBackup                               No
# DeviceProtection                          Yes
# TechSupport                               Yes
# StreamingTV                               Yes
# StreamingMovies                            No
# Contract                             Two year
# PaperlessBilling                          Yes
# PaymentMethod       Bank transfer (automatic)
# MonthlyCharges                          52.55
# TotalCharges
# Churn                                      No
# ...

# %%
# blank remove needed

data['TotalCharges'] = data['TotalCharges'].replace(" ","")
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'])

# %%
# 바뀐 Dtype 확인

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7032.000000
# mean        0.162147    32.371149       64.761692   2283.300441
# std         0.368612    24.559481       30.090047   2266.771362
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.850000   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
sns.displot(data['TotalCharges'])

# %% [markdown]
# ## Category Value 처리
#
# 데이터 특성을 살펴본 결과 category형 value가 다수 나타남 (ex: male/female)
# 단순히 숫자 (0/1 등)으로 대치할 경우 value간의 서열이 나타나기 때문에
# 바람직하지 않은 경우가 발생
# gender(male/female) 대신 male(0/1), female(0/1) 등 새로운 컬럼을 만들어서
# 대치할 수 있다.
# 성적이나 만족도 등 value의 서열이 명확한 경우 연속적 숫자로 나타내도 무관

# %%
data['gender'].nunique()
# Out:
# 2

# %%
# gender_Female값의 True/False에 따라 gender_Male값을 확정할 수 있으므로
# 한 가지 column만 만들어도 충분하다. 

pd.get_dummies(data, columns=['gender'], drop_first=True)
# Out:
#       customerID  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     7590-VHVEG              0     Yes         No       1           No
# 1     5575-GNVDE              0      No         No      34          Yes
# 2     3668-QPYBK              0      No         No       2          Yes
# 3     7795-CFOCW              0      No         No      45           No
# 4     9237-HQITU              0      No         No       2          Yes
# ...          ...            ...     ...        ...     ...          ...
# 7038  6840-RESVB              0     Yes        Yes      24          Yes
# 7039  2234-XADUH              0     Yes        Yes      72          Yes
# 7040  4801-JZAZL              0     Yes        Yes      11           No
# 7041  8361-LTMKD              1     Yes         No       4          Yes
# 7042  3186-AJIEK              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# ...

# %%
# 대치해야 할 category형 column이 다수 관측된다.
# 우선 data type이 object인 column들을 모두 분별한다.

col_list = []
for i in data.columns:
    if data[i].dtype == 'O': col_list.append(i)
col_list
# Out:
# ['customerID',
#  'gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Churn']

# %%
# data type이 object인 column 중 category형 value를 가진 column을 판별한다.

for i in col_list:
    print(i, data[i].nunique())
# Out:
# customerID 7043
# gender 2
# Partner 2
# Dependents 2
# PhoneService 2
# MultipleLines 3
# InternetService 3
# OnlineSecurity 3
# OnlineBackup 3
# DeviceProtection 3
# TechSupport 3
# StreamingTV 3
# StreamingMovies 3
# Contract 3
# PaperlessBilling 2
# PaymentMethod 4
# Churn 2

# %%
# customerID 외의 모든 column들이 category형 value를 가지므로 해당 column만 제거

col_list = col_list[1:]

# %%
# category형 value를 가진 column들을 분별했으므로 get_dummies를 통해 처리한다.

data = pd.get_dummies(data, columns=col_list, drop_first=True)

# %% [markdown]
# column의 nunique값이 크더라도 대치가 필요한 경우
# 주어진 데이터를 일부 변환하여 get_dummies로 처리할 수 있을 것이다.
# ex) 휴대폰 제조사를 삼성, 애플, 기타의 세 가지 category로 변환

# %% [markdown]
# ## Missing Value 확인 및 처리

# %%
data.isna().sum()
# Out:
# customerID                                0
# SeniorCitizen                             0
# tenure                                    0
# MonthlyCharges                            0
# TotalCharges                             11
# gender_Male                               0
# Partner_Yes                               0
# Dependents_Yes                            0
# PhoneService_Yes                          0
# MultipleLines_No phone service            0
# MultipleLines_Yes                         0
# InternetService_Fiber optic               0
# InternetService_No                        0
# OnlineSecurity_No internet service        0
# OnlineSecurity_Yes                        0
# OnlineBackup_No internet service          0
# OnlineBackup_Yes                          0
# DeviceProtection_No internet service      0
# DeviceProtection_Yes                      0
# TechSupport_No internet service           0
# TechSupport_Yes                           0
# ...

# %%
data['TotalCharges'].mean()
# Out:
# 2283.3004408418656

# %%
data['TotalCharges'].medianian()
# Out:
# 1397.475

# %%
# 평균과 중간값의 편차가 크므로 데이터의 치우침이나 이상치가 있는지 확인

sns.displot(data['TotalCharges'])

# %%
# 0에 가까운 숫자들이 훨씬 많으므로 mean 대신 median 값으로 대체

data['TotalCharges'] = data['TotalCharges'].fillna(data['TotalCharges'].median())

# %%
# 잘 대체되었는지 확인

data.isna().sum()
# Out:
# customerID                               0
# SeniorCitizen                            0
# tenure                                   0
# MonthlyCharges                           0
# TotalCharges                             0
# gender_Male                              0
# Partner_Yes                              0
# Dependents_Yes                           0
# PhoneService_Yes                         0
# MultipleLines_No phone service           0
# MultipleLines_Yes                        0
# InternetService_Fiber optic              0
# InternetService_No                       0
# OnlineSecurity_No internet service       0
# OnlineSecurity_Yes                       0
# OnlineBackup_No internet service         0
# OnlineBackup_Yes                         0
# DeviceProtection_No internet service     0
# DeviceProtection_Yes                     0
# TechSupport_No internet service          0
# TechSupport_Yes                          0
# StreamingTV_No internet service          0
# ...
